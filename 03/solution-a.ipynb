# %%
from aocd import get_data, submit

data = get_data(day=3, year=2023)
data = data.split('\n')
data

# %%
import re

pos_registry = {}

def num_at_pos(line_number, pos):
  query = r'[0-9]+'
  result_iter = re.finditer(query, data[line_number])

  for result in result_iter:
    if pos >= result.start() and pos < result.end():
      number = result.group()

      try:
        return (int(number), (line_number, result.start(), result.end()))
      except Exception:
        return None

def add_position(line_number, pos):
  n_at_p = num_at_pos(line_number, pos)

  if n_at_p:
    print(f'Add to registry {n_at_p}')
    pos_registry[n_at_p[1]] = n_at_p[0]
    print(pos_registry)

  return n_at_p

def extract_part_no(pos, line_number, line, size):
  # Boundry checks
  left_pos = pos-1 if (pos-1) >= 0 else -1
  right_pos = pos+1 if (pos+1) < len(line) else -1
  up_pos = line_number-1 if (line_number-1) >= 0 else -1
  down_pos = line_number+1 if (line_number+1) < size else -1

  l = 0
  r = 0
  u = 0
  d = 0
  ul = 0
  ur = 0
  dl = 0
  dr = 0

  if left_pos >= 0:
    l = (line_number, pos-1)
    p =add_position(*l)
    print(f'l {p}')

  if right_pos >= 0:
    r = (line_number, pos+1)
    p = add_position(*r)
    print(f'r {p}')

  if up_pos >= 0:
    u = (line_number-1, pos)
    p = add_position(*u)
    print(f'u {p}')

  if down_pos >= 0:
    d = (line_number+1, pos)
    p = add_position(*d)
    print(f'd {p}')

  if up_pos >= 0 and left_pos >= 0:
    ul = (line_number-1, pos-1)
    p = add_position(*ul)
    print(f'ul {p}')

  if up_pos >= 0 and right_pos >= 0:
    ur = (line_number-1, pos+1)
    p = add_position(*ur)
    print(f'ur {p}')

  if down_pos >= 0 and left_pos >= 0:
    dl = (line_number+1, pos-1)
    p = add_position(*dl)
    print(f'dl {p}')

  if down_pos >= 0 and right_pos >= 0:
    dr = (line_number+1, pos+1)
    p = add_position(*dr)
    print(f'dr {p}')

def symbol_pos(line):
  query = r'[^0-9|\.]'  # Find all non digit and not '.' charecters
  result_iter = re.finditer(query, line)

  return [symbol.start() for symbol in result_iter]

# %%
for index, line in enumerate(data):
  symbol_postions = symbol_pos(line)
  print(f'Line: {index}: symbols found: {len(symbol_postions)}')

  for pos in symbol_postions:
    print(f'Symbol at pos: {pos}')
    extract_part_no(pos, index, line, len(data))

  print('')

sum = 0
print(len(pos_registry))
for p in pos_registry:

  print(f'{p}: {pos_registry[p]}')
  sum = sum + pos_registry[p]

print(sum)
